# %% [markdown]
# # EKSTRAKSI PALET WARNA UNTUK KOMPRESI GAMBAR DIGITAL MENGGUNAKAN ALGORITMA K-MEANS
#
# TUGAS AKHIR
#
# Ahmad Ma'ruf
# NIM. 2020150012
#
# Teknik Informatika
# Fakultas Teknik dan Ilmu Komputer
# Universitas Sains Al-Qur'an Jawa Tengah di Wonosobo
# 2024

# %%
# uncompressing dataset (img file)
# !unzip "./source.zip"
# Out:
# Archive:  ./source.zip
#    creating: source/
#   inflating: source/a1.jpg
#   inflating: source/a2.jpg
#   inflating: source/a3.jpg
#   inflating: source/attribution.csv
#   inflating: source/b1.jpg
#   inflating: source/b2.jpg
#   inflating: source/b3.jpg
#   inflating: source/c1.jpg
#   inflating: source/c2.jpg
#   inflating: source/c3.jpg
#   inflating: source/d1.jpg
#   inflating: source/d2.jpg
#   inflating: source/d3.jpg

# %%
# Import library
import os
from io import BytesIO
from typing import Tuple
import numpy as np
from PIL import Image
from sklearn.cluster import KMeans
import datetime
from time import time
import csv

# %%
# create function for extracting experiment id
def extract_id(id: str, separator : str):
  # Split the experiment ID into its components
    components = id.split(separator)

    # Extract file name, K value, and experiment number
    file = f"{components[0]}.jpg"
    k = int(components[1])
    p = int(components[2])

    return file, k, p

# %%
# load image function. load image file as PIL Object
def load_img(path: str):
  return Image.open(path)

# %%
# Color palette generator (K-Means)
def get_color_palette(img: Image, n_color: int) -> Tuple[np.ndarray, KMeans]:
  """
  Extracts a color palette from an image using K-Means clustering.

  Args:
      img: PIL Image object representing the input image.
      n_color: The desired number of colors in the resulting palette.

  Returns:
      A tuple containing:
          - palette (np.ndarray): A NumPy array representing the color palette (RGB values).
          - kmeans (KMeans): The fitted KMeans model object.
  """
  # RESIZE into half
  width, height = img.size
  new_size = (width//2, height//2)
  resized_image = img.resize(new_size)

  # Convert the PIL Image to a NumPy array and normalize pixel values  to range [0, 1]
  img = np.asarray(resized_image) / 255.0

  # Get the image dimensions (height, width, and number of channels)
  h, w, c = img.shape

  # Reshape the image data for K-Means clustering
  """
  This line reshapes the image data into a 2D array. Each row represents a pixel,
  and the columns represent the color channels (e.g., Red, Green, Blue). This format
  is suitable for K-Means clustering, which operates on data points.
  """
  img_arr = img.reshape(h * w, c)

  # Perform K-Means clustering to identify representative colors
  # Multiply by 255 to convert back to original pixel value range (0-255)
  kmeans = KMeans(n_clusters=n_color, n_init="auto").fit(img_arr)

  # Extract the cluster centers (centroids) as the color palette
  palette = np.asarray(kmeans.cluster_centers_ * 255,).astype(int)

  # Return the color palette and the fitted KMeans model
  return palette, kmeans

# %%
def quantize_img(img: Image, kmeans: KMeans) -> np.ndarray:
  """
  Quantizes an image using a pre-trained KMeans model.

  Args:
      img: PIL Image object representing the input image.
      kmeans: A fitted KMeans model object used for color quantization.

  Returns:
      A NumPy array representing the quantized image.
  """

  # Convert the PIL Image to a NumPy array and normalize pixel values to range [0, 1]
  img_np = np.asarray(img) / 255.0

  # Get the image dimensions (height, width, and number of channels)
  h, w, c = img_np.shape

  # Reshape the image data into a 2D array for KMeans prediction
  flatten = img_np.reshape(h * w, c)

  # Predict cluster labels for each pixel using the KMeans model
  # The output is an array containing the predicted cluster label (integer)
  pixel_rgb_clusters = kmeans.predict(flatten)

  # Quantize image by assigning cluster centers (centroids) to pixels
  img_quantized = kmeans.cluster_centers_[pixel_rgb_clusters]

  # Reshape the quantized image back to its original dimensions
  return img_quantized.reshape(h, w, c)

# %%
def save_quantized_img(quantized_img: np.ndarray, filename: str, resize_factor=0.6):
  """
  Saves a quantized image as a JPG file.

  Args:
      quantized_img: A NumPy array representing the quantized image.
      filename: The desired filename (including '.jpg' extension) to save the image.
  """

  pixel_array_uint8 = (quantized_img * 255).astype(np.uint8)

  # Convert the quantized image back to a PIL Image object
  quantized_image = Image.fromarray(pixel_array_uint8)

  if resize_factor < 1:  # Only resize if a scaling factor is provided (between 0 and 1)
      # Get the original dimensions
      w, h = quantized_image.size

      # Calculate the new dimensions for 75% size
      new_w = int(w * resize_factor)
      new_h = int(h * resize_factor)

      # Resize the image using PIL's resize method
      quantized_image = quantized_image.resize((new_w, new_h), Image.Resampling.LANCZOS)  # Use ANTIALIAS for smoother resizing

  # Save the quantized image as a JPEG
  quantized_image.save(filename, optimize=True, quality=80)

# %%
def save_quantized_img(
    quantized_img: np.ndarray,
    filename: str, resize_factor=0.6):
  """
  Saves a quantized image as a JPG file.
  Args:
      quantized_img: A NumPy array of the quantized image.
      filename: The desired filename
      resize_factor: A scaling factor to resize the image.
  """

  pixel_array_uint8 = (quantized_img * 255).astype(np.uint8)

  # Convert the quantized image back to a PIL Image object
  quantized_image = Image.fromarray(pixel_array_uint8)

  if resize_factor < 1:
      # Get the original dimensions
      w, h = quantized_image.size

      # Calculate the new dimensions
      new_w = int(w * resize_factor)
      new_h = int(h * resize_factor)

      # Resize the image using PIL's resize method
      quantized_image = quantized_image.resize(
          (new_w, new_h),
          Image.Resampling.LANCZOS)

  # Save the quantized image as a JPEG
  quantized_image.save(filename, optimize=True, quality=80)

# %%
def calculate_mse_psnr_metrics(original_img: np.ndarray, quantized_img: np.ndarray) -> (float, float):
  """
  Calculates Mean Squared Error (MSE) and Peak Signal-to-Noise Ratio (PSNR) between two images.

  Args:
      original_img: A NumPy array representing the original image.
      quantized_img: A NumPy array representing the quantized image.

  Returns:
      A tuple containing:
          - mse (float): The Mean Squared Error between the images.
          - psnr (float): The Peak Signal-to-Noise Ratio between the images.
  """

  # Calculate Mean Squared Error (MSE)
  # Square the difference and compute mean
  mse = np.mean(np.square(original_img - quantized_img))

  # Calculate Peak Signal-to-Noise Ratio (PSNR)
  max_intensity = 255.0
  psnr = 10 * np.log10(max_intensity**2 / mse)

  return mse, psnr

# %%
def calculate_mse_psnr_metrics(
    original_img: np.ndarray,
    quantized_img: np.ndarray) -> (float, float):
  """
  Calculates Mean Squared Error (MSE)
  and Peak Signal-to-Noise Ratio (PSNR)
  Args:
      original_img: A NumPy of the original image.
      quantized_img: A NumPy of the quantized image.

  Returns:
      A tuple containing:
          - mse (float):
          - psnr (float):
  """

  # Calculate Mean Squared Error (MSE)
  # Square the difference and compute mean
  mse = np.mean(
      np.square(original_img - quantized_img))

  # Calculate Peak Signal-to-Noise Ratio (PSNR)
  max_intensity = 255.0
  psnr = 10 * np.log10(max_intensity**2 / mse)

  return mse, psnr

# %%
def calculate_compression_ratio(original_img_path: str, compressed_img_path: str):
  """
  Calculates the compression ratio achieved by comparing the original and compressed image sizes.

  This function takes the paths to the original and compressed image files and calculates the compression ratio.
  A higher compression ratio indicates that the compressed image is significantly smaller than the original image.

  Args:
      original_img_path: Path to the original image file (e.g., "path/to/image.jpg").
      compressed_img_path: Path to the compressed image file (e.g., "compressed_image.jpg").

  Returns:
      The compression ratio (float) between 0 and 1, where 1 indicates higher compression
      (compressed image size is much smaller than the original).
  """

  original_size = os.path.getsize(original_img_path)
  compressed_size = os.path.getsize(compressed_img_path)

  compression_ratio = 1 - (compressed_size / original_size)

  return compression_ratio, original_size, compressed_size

# %% [markdown]
# ## Start Experiment

# %%
# SOURCE IMG FOLDER
sourcepath = './source'

# CREATE RESULT FOLDER
now = datetime.datetime.now()

# Adjust for GMT+7 assuming your system clock reflects it
offset_hours = 7
now = now + datetime.timedelta(hours=offset_hours)
formatted_datetime = now.strftime("%y%m%d_%H-%M")  # YYMMDD_H-M format

# RESULT PATH
resultpath = os.path.join("./", formatted_datetime)

# Create the folder if it doesn't exist
if not os.path.exists(resultpath):
  os.makedirs(resultpath)

# %%
# Nama file gambar yang akan digunakan
files = [
    'a1', 'a2', 'a3', 'b1', 'b2', 'b3',
    'c1', 'c2', 'c3', 'd1', 'd2', 'd3'
]

k_number = [8,16,32,64,96,128] # Jumlah Klaster
exp_count = [1,2,3] # index percobaan

# GENERATE EXPERIMENT IDs
exp_ids = [
    f"{file}_{k}_{cnt}"
    for file in files
    for k in k_number
    for cnt in exp_count
]

print("Jumlah eksperimen: " + str(len(exp_ids)))
print("ID eksperimen :")
print(exp_ids)
# Out:
# Jumlah eksperimen: 216
# ID eksperimen :
# ['a1_8_1', 'a1_8_2', 'a1_8_3', 'a1_16_1', 'a1_16_2', 'a1_16_3', 'a1_32_1', 'a1_32_2', 'a1_32_3', 'a1_64_1', 'a1_64_2', 'a1_64_3', 'a1_96_1', 'a1_96_2', 'a1_96_3', 'a1_128_1', 'a1_128_2', 'a1_128_3', 'a2_8_1', 'a2_8_2', 'a2_8_3', 'a2_16_1', 'a2_16_2', 'a2_16_3', 'a2_32_1', 'a2_32_2', 'a2_32_3', 'a2_64_1', 'a2_64_2', 'a2_64_3', 'a2_96_1', 'a2_96_2', 'a2_96_3', 'a2_128_1', 'a2_128_2', 'a2_128_3', 'a3_8_1', 'a3_8_2', 'a3_8_3', 'a3_16_1', 'a3_16_2', 'a3_16_3', 'a3_32_1', 'a3_32_2', 'a3_32_3', 'a3_64_1', 'a3_64_2', 'a3_64_3', 'a3_96_1', 'a3_96_2', 'a3_96_3', 'a3_128_1', 'a3_128_2', 'a3_128_3', 'b1_8_1', 'b1_8_2', 'b1_8_3', 'b1_16_1', 'b1_16_2', 'b1_16_3', 'b1_32_1', 'b1_32_2', 'b1_32_3', 'b1_64_1', 'b1_64_2', 'b1_64_3', 'b1_96_1', 'b1_96_2', 'b1_96_3', 'b1_128_1', 'b1_128_2', 'b1_128_3', 'b2_8_1', 'b2_8_2', 'b2_8_3', 'b2_16_1', 'b2_16_2', 'b2_16_3', 'b2_32_1', 'b2_32_2', 'b2_32_3', 'b2_64_1', 'b2_64_2', 'b2_64_3', 'b2_96_1', 'b2_96_2', 'b2_96_3', 'b2_128_1', 'b2_128_2', 'b2_128_3', 'b3_8_1', 'b3_8_2', 'b3_8_3', 'b3_16_1', 'b3_16_2', 'b3_16_3', 'b3_32_1', 'b3_32_2', 'b3_32_3', 'b3_64_1', 'b3_64_2', 'b3_64_3', 'b3_96_1', 'b3_96_2', 'b3_96_3', 'b3_128_1', 'b3_128_2', 'b3_128_3', 'c1_8_1', 'c1_8_2', 'c1_8_3', 'c1_16_1', 'c1_16_2', 'c1_16_3', 'c1_32_1', 'c1_32_2', 'c1_32_3', 'c1_64_1', 'c1_64_2', 'c1_64_3', 'c1_96_1', 'c1_96_2', 'c1_96_3', 'c1_128_1', 'c1_128_2', 'c1_128_3', 'c2_8_1', 'c2_8_2', 'c2_8_3', 'c2_16_1', 'c2_16_2', 'c2_16_3', 'c2_32_1', 'c2_32_2', 'c2_32_3', 'c2_64_1', 'c2_64_2', 'c2_64_3', 'c2_96_1', 'c2_96_2', 'c2_96_3', 'c2_128_1', 'c2_128_2', 'c2_128_3', 'c3_8_1', 'c3_8_2', 'c3_8_3', 'c3_16_1', 'c3_16_2', 'c3_16_3', 'c3_32_1', 'c3_32_2', 'c3_32_3', 'c3_64_1', 'c3_64_2', 'c3_64_3', 'c3_96_1', 'c3_96_2', 'c3_96_3', 'c3_128_1', 'c3_128_2', 'c3_128_3', 'd1_8_1', 'd1_8_2', 'd1_8_3', 'd1_16_1', 'd1_16_2', 'd1_16_3', 'd1_32_1', 'd1_32_2', 'd1_32_3', 'd1_64_1', 'd1_64_2', 'd1_64_3', 'd1_96_1', 'd1_96_2', 'd1_96_3', 'd1_128_1', 'd1_128_2', 'd1_128_3', 'd2_8_1', 'd2_8_2', 'd2_8_3', 'd2_16_1', 'd2_16_2', 'd2_16_3', 'd2_32_1', 'd2_32_2', 'd2_32_3', 'd2_64_1', 'd2_64_2', 'd2_64_3', 'd2_96_1', 'd2_96_2', 'd2_96_3', 'd2_128_1', 'd2_128_2', 'd2_128_3', 'd3_8_1', 'd3_8_2', 'd3_8_3', 'd3_16_1', 'd3_16_2', 'd3_16_3', 'd3_32_1', 'd3_32_2', 'd3_32_3', 'd3_64_1', 'd3_64_2', 'd3_64_3', 'd3_96_1', 'd3_96_2', 'd3_96_3', 'd3_128_1', 'd3_128_2', 'd3_128_3']

# %%
csv_headers = ["id","img_type", "k",
               "mse", "psnr", "original_size",
               "compressed_size", "cr", "comp_time"]

result = []
count = 1;
start_compute = time();
for exp_id in exp_ids:
  start_time = time()  # Start time measurement

  file, k, p = extract_id(exp_id, "_")

  source_img_path = f"{sourcepath}/{file}"
  result_img_path = f"{resultpath}/{exp_id}.jpg"

  image = load_img(source_img_path)
  palette, k_means = get_color_palette(image, k)
  quantized_img = quantize_img(image, k_means)
  save_quantized_img(quantized_img, result_img_path)

  img_np = np.asarray(image) / 255.0
  mse, psnr = calculate_mse_psnr_metrics(
      img_np, quantized_img)

  compression_ratio, original_size, compressed_size =  calculate_compression_ratio(
      source_img_path, result_img_path)

  computation_time = time() - start_time

  # CONVERT THE VALUE INTO float positional notation
  converted_mse = f"{mse:.7f}"
  converted_psnr = f"{psnr:.2f}"
  converted_compression_ratio = f"{compression_ratio:.2f}"
  converted_computation_time = f"{computation_time:.2f}"

  res = [exp_id, exp_id[0], k,
         converted_mse, converted_psnr,
         original_size, compressed_size,
         converted_compression_ratio,
         converted_computation_time]

  result.append(res)

  print(f"""
  Percobaan ke {count}
    ID : {exp_id}
    MSE: {converted_mse}
    PSNR: {converted_psnr}
    CR: {converted_compression_ratio}
    Time: {converted_computation_time}
  """)
  count += 1

total_compute = time() - start_compute

print(f"total computational time {total_compute/60} minutes")
# Out:
#   Percobaan ke 1
#     ID : a1_8_1
#     MSE: 0.0034487
#     PSNR: 72.75
#     CR: 0.47
#     Time: 0.32
#
#
#   Percobaan ke 2
#     ID : a1_8_2
#     MSE: 0.0034506
#     PSNR: 72.75
#     CR: 0.47
#     Time: 0.16
#
#
#   Percobaan ke 3
#     ID : a1_8_3
#     MSE: 0.0031700
#     PSNR: 73.12
#     CR: 0.46
#     Time: 0.21
#
#
#   Percobaan ke 4
#     ID : a1_16_1
#     MSE: 0.0014842
#     PSNR: 76.42
#     CR: 0.46
#     Time: 0.22
#
#
#   Percobaan ke 5
#     ID : a1_16_2
#     MSE: 0.0014836
#     PSNR: 76.42
#     CR: 0.46
#     Time: 0.28
#
#
#   Percobaan ke 6
#     ID : a1_16_3
#     MSE: 0.0015051
#     PSNR: 76.36
#     CR: 0.46
#     Time: 0.25
#
#
#   Percobaan ke 7
#     ID : a1_32_1
#     MSE: 0.0007864
#     PSNR: 79.17
#     CR: 0.47
#     Time: 0.41
#
#
#   Percobaan ke 8
#     ID : a1_32_2
#     MSE: 0.0007817
#     PSNR: 79.20
#     CR: 0.47
#     Time: 0.40
#
#
#   Percobaan ke 9
#     ID : a1_32_3
#     MSE: 0.0007871
#     PSNR: 79.17
#     CR: 0.47
#     Time: 0.35
#
#
#   Percobaan ke 10
#     ID : a1_64_1
#     MSE: 0.0004557
#     PSNR: 81.54
#     CR: 0.47
#     Time: 0.77
#
#
#   Percobaan ke 11
#     ID : a1_64_2
#     MSE: 0.0004555
#     PSNR: 81.55
#     CR: 0.47
#     Time: 0.72
#
#
#   Percobaan ke 12
#     ID : a1_64_3
#     MSE: 0.0004491
#     PSNR: 81.61
#     CR: 0.47
#     Time: 0.73
#
#
#   Percobaan ke 13
#     ID : a1_96_1
#     MSE: 0.0003358
#     PSNR: 82.87
#     CR: 0.47
#     Time: 1.18
#
#
#   Percobaan ke 14
#     ID : a1_96_2
#     MSE: 0.0003362
#     PSNR: 82.87
#     CR: 0.47
#     Time: 1.17
#
#
#   Percobaan ke 15
#     ID : a1_96_3
#     MSE: 0.0003405
#     PSNR: 82.81
#     CR: 0.47
#     Time: 1.46
#
#
#   Percobaan ke 16
#     ID : a1_128_1
#     MSE: 0.0002743
#     PSNR: 83.75
#     CR: 0.47
#     Time: 3.09
#
#
#   Percobaan ke 17
#     ID : a1_128_2
#     MSE: 0.0002725
#     PSNR: 83.78
#     CR: 0.47
#     Time: 1.47
#
#
#   Percobaan ke 18
#     ID : a1_128_3
#     MSE: 0.0002733
#     PSNR: 83.76
#     CR: 0.47
#     Time: 2.03
#
#
#   Percobaan ke 19
#     ID : a2_8_1
#     MSE: 0.0007853
#     PSNR: 79.18
#     CR: 0.64
#     Time: 0.22
#
#
#   Percobaan ke 20
#     ID : a2_8_2
#     MSE: 0.0007875
#     PSNR: 79.17
#     CR: 0.65
#     Time: 0.18
#
#
#   Percobaan ke 21
#     ID : a2_8_3
#     MSE: 0.0007853
#     PSNR: 79.18
#     CR: 0.64
#     Time: 0.17
#
#
#   Percobaan ke 22
#     ID : a2_16_1
#     MSE: 0.0004432
#     PSNR: 81.66
#     CR: 0.64
#     Time: 0.26
#
#
#   Percobaan ke 23
#     ID : a2_16_2
#     MSE: 0.0004277
#     PSNR: 81.82
#     CR: 0.64
#     Time: 0.28
#
#
#   Percobaan ke 24
#     ID : a2_16_3
#     MSE: 0.0004413
#     PSNR: 81.68
#     CR: 0.65
#     Time: 0.24
#
#
#   Percobaan ke 25
#     ID : a2_32_1
#     MSE: 0.0002210
#     PSNR: 84.69
#     CR: 0.64
#     Time: 0.32
#
#
#   Percobaan ke 26
#     ID : a2_32_2
#     MSE: 0.0002186
#     PSNR: 84.74
#     CR: 0.64
#     Time: 0.48
#
#
#   Percobaan ke 27
#     ID : a2_32_3
#     MSE: 0.0002193
#     PSNR: 84.72
#     CR: 0.64
#     Time: 0.47
#
#
#   Percobaan ke 28
#     ID : a2_64_1
#     MSE: 0.0001189
#     PSNR: 87.38
#     CR: 0.64
#     Time: 0.82
#
#
#   Percobaan ke 29
#     ID : a2_64_2
#     MSE: 0.0001178
#     PSNR: 87.42
#     CR: 0.64
#     Time: 0.71
#
#
#   Percobaan ke 30
#     ID : a2_64_3
#     MSE: 0.0001186
#     PSNR: 87.39
#     CR: 0.64
#     Time: 1.17
#
#
#   Percobaan ke 31
#     ID : a2_96_1
#     MSE: 0.0000859
#     PSNR: 88.79
#     CR: 0.64
#     Time: 2.55
#
#
#   Percobaan ke 32
#     ID : a2_96_2
#     MSE: 0.0000863
#     PSNR: 88.77
#     CR: 0.64
#     Time: 1.86
#
#
#   Percobaan ke 33
#     ID : a2_96_3
#     MSE: 0.0000877
#     PSNR: 88.70
#     CR: 0.64
#     Time: 0.84
#
#
#   Percobaan ke 34
#     ID : a2_128_1
#     MSE: 0.0000720
#     PSNR: 89.56
#     CR: 0.64
#     Time: 1.69
#
#
#   Percobaan ke 35
#     ID : a2_128_2
#     MSE: 0.0000716
#     PSNR: 89.58
#     CR: 0.64
#     Time: 1.53
#
#
#   Percobaan ke 36
#     ID : a2_128_3
#     MSE: 0.0000714
#     PSNR: 89.60
#     CR: 0.64
#     Time: 1.65
#
#
#   Percobaan ke 37
#     ID : a3_8_1
#     MSE: 0.0008365
#     PSNR: 78.91
#     CR: 0.71
#     Time: 0.23
#
#
#   Percobaan ke 38
#     ID : a3_8_2
#     MSE: 0.0008335
#     PSNR: 78.92
#     CR: 0.71
#     Time: 0.15
#
#
#   Percobaan ke 39
#     ID : a3_8_3
#     MSE: 0.0008335
#     PSNR: 78.92
#     CR: 0.71
#     Time: 0.17
#
#
#   Percobaan ke 40
#     ID : a3_16_1
#     MSE: 0.0002221
#     PSNR: 84.66
#     CR: 0.71
#     Time: 0.20
#
#
#   Percobaan ke 41
#     ID : a3_16_2
#     MSE: 0.0002232
#     PSNR: 84.64
#     CR: 0.71
#     Time: 0.16
#
#
#   Percobaan ke 42
#     ID : a3_16_3
#     MSE: 0.0002224
#     PSNR: 84.66
#     CR: 0.71
#     Time: 0.19
#
#
#   Percobaan ke 43
#     ID : a3_32_1
#     MSE: 0.0000598
#     PSNR: 90.36
#     CR: 0.72
#     Time: 0.26
#
#
#   Percobaan ke 44
#     ID : a3_32_2
#     MSE: 0.0000579
#     PSNR: 90.50
#     CR: 0.72
#     Time: 0.26
#
#
#   Percobaan ke 45
#     ID : a3_32_3
#     MSE: 0.0000591
#     PSNR: 90.41
#     CR: 0.72
#     Time: 0.28
#
#
#   Percobaan ke 46
#     ID : a3_64_1
#     MSE: 0.0000144
#     PSNR: 96.53
#     CR: 0.72
#     Time: 0.42
#
#
#   Percobaan ke 47
#     ID : a3_64_2
#     MSE: 0.0000145
#     PSNR: 96.51
#     CR: 0.72
#     Time: 0.45
#
#
#   Percobaan ke 48
#     ID : a3_64_3
#     MSE: 0.0000147
#     PSNR: 96.45
#     CR: 0.72
#     Time: 0.41
#
#
#   Percobaan ke 49
#     ID : a3_96_1
#     MSE: 0.0000066
#     PSNR: 99.96
#     CR: 0.72
#     Time: 0.85
#
#
#   Percobaan ke 50
#     ID : a3_96_2
#     MSE: 0.0000067
#     PSNR: 99.89
#     CR: 0.72
#     Time: 1.89
#
#
#   Percobaan ke 51
#     ID : a3_96_3
#     MSE: 0.0000069
#     PSNR: 99.76
#     CR: 0.72
#     Time: 1.10
#
#
#   Percobaan ke 52
#     ID : a3_128_1
#     MSE: 0.0000037
#     PSNR: 102.46
#     CR: 0.72
#     Time: 0.74
#
#
#   Percobaan ke 53
#     ID : a3_128_2
#     MSE: 0.0000035
#     PSNR: 102.70
#     CR: 0.72
#     Time: 0.79
#
#
#   Percobaan ke 54
#     ID : a3_128_3
#     MSE: 0.0000037
#     PSNR: 102.45
#     CR: 0.72
#     Time: 0.80
#
#
#   Percobaan ke 55
#     ID : b1_8_1
#     MSE: 0.0039445
#     PSNR: 72.17
#     CR: 0.70
#     Time: 0.23
#
#
#   Percobaan ke 56
#     ID : b1_8_2
#     MSE: 0.0037875
#     PSNR: 72.35
#     CR: 0.70
#     Time: 0.22
#
#
#   Percobaan ke 57
#     ID : b1_8_3
#     MSE: 0.0037844
#     PSNR: 72.35
#     CR: 0.70
#     Time: 0.32
#
#
#   Percobaan ke 58
#     ID : b1_16_1
#     MSE: 0.0019143
#     PSNR: 75.31
#     CR: 0.69
#     Time: 0.40
#
#
#   Percobaan ke 59
#     ID : b1_16_2
#     MSE: 0.0019480
#     PSNR: 75.23
#     CR: 0.69
#     Time: 0.34
#
#
#   Percobaan ke 60
#     ID : b1_16_3
#     MSE: 0.0018918
#     PSNR: 75.36
#     CR: 0.69
#     Time: 0.39
#
#
#   Percobaan ke 61
#     ID : b1_32_1
#     MSE: 0.0010243
#     PSNR: 78.03
#     CR: 0.69
#     Time: 0.73
#
#
#   Percobaan ke 62
#     ID : b1_32_2
#     MSE: 0.0010231
#     PSNR: 78.03
#     CR: 0.69
#     Time: 0.85
#
#
#   Percobaan ke 63
#     ID : b1_32_3
#     MSE: 0.0010282
#     PSNR: 78.01
#     CR: 0.69
#     Time: 0.73
#
#
#   Percobaan ke 64
#     ID : b1_64_1
#     MSE: 0.0005783
#     PSNR: 80.51
#     CR: 0.69
#     Time: 1.35
#
#
#   Percobaan ke 65
#     ID : b1_64_2
#     MSE: 0.0005752
#     PSNR: 80.53
#     CR: 0.69
#     Time: 1.49
#
#
#   Percobaan ke 66
#     ID : b1_64_3
#     MSE: 0.0005742
#     PSNR: 80.54
#     CR: 0.69
#     Time: 1.65
#
#
#   Percobaan ke 67
#     ID : b1_96_1
#     MSE: 0.0004171
#     PSNR: 81.93
#     CR: 0.69
#     Time: 3.44
#
#
#   Percobaan ke 68
#     ID : b1_96_2
#     MSE: 0.0004179
#     PSNR: 81.92
#     CR: 0.69
#     Time: 3.63
#
#
#   Percobaan ke 69
#     ID : b1_96_3
#     MSE: 0.0004191
#     PSNR: 81.91
#     CR: 0.69
#     Time: 2.25
#
#
#   Percobaan ke 70
#     ID : b1_128_1
#     MSE: 0.0003367
#     PSNR: 82.86
#     CR: 0.69
#     Time: 2.97
#
#
#   Percobaan ke 71
#     ID : b1_128_2
#     MSE: 0.0003377
#     PSNR: 82.85
#     CR: 0.69
#     Time: 5.38
#
#
#   Percobaan ke 72
#     ID : b1_128_3
#     MSE: 0.0003388
#     PSNR: 82.83
#     CR: 0.69
#     Time: 3.12
#
#
#   Percobaan ke 73
#     ID : b2_8_1
#     MSE: 0.0018158
#     PSNR: 75.54
#     CR: 0.67
#     Time: 0.25
#
#
#   Percobaan ke 74
#     ID : b2_8_2
#     MSE: 0.0016962
#     PSNR: 75.84
#     CR: 0.66
#     Time: 0.32
#
#
#   Percobaan ke 75
#     ID : b2_8_3
#     MSE: 0.0016966
#     PSNR: 75.83
#     CR: 0.66
#     Time: 0.36
#
#
#   Percobaan ke 76
#     ID : b2_16_1
#     MSE: 0.0007690
#     PSNR: 79.27
#     CR: 0.66
#     Time: 0.36
#
#
#   Percobaan ke 77
#     ID : b2_16_2
#     MSE: 0.0007665
#     PSNR: 79.29
#     CR: 0.66
#     Time: 0.41
#
#
#   Percobaan ke 78
#     ID : b2_16_3
#     MSE: 0.0007532
#     PSNR: 79.36
#     CR: 0.66
#     Time: 0.36
#
#
#   Percobaan ke 79
#     ID : b2_32_1
#     MSE: 0.0003866
#     PSNR: 82.26
#     CR: 0.67
#     Time: 0.58
#
#
#   Percobaan ke 80
#     ID : b2_32_2
#     MSE: 0.0003952
#     PSNR: 82.16
#     CR: 0.67
#     Time: 0.65
#
#
#   Percobaan ke 81
#     ID : b2_32_3
#     MSE: 0.0003834
#     PSNR: 82.29
#     CR: 0.67
#     Time: 0.88
#
#
#   Percobaan ke 82
#     ID : b2_64_1
#     MSE: 0.0002118
#     PSNR: 84.87
#     CR: 0.67
#     Time: 1.64
#
#
#   Percobaan ke 83
#     ID : b2_64_2
#     MSE: 0.0002100
#     PSNR: 84.91
#     CR: 0.67
#     Time: 2.00
#
#
#   Percobaan ke 84
#     ID : b2_64_3
#     MSE: 0.0002155
#     PSNR: 84.80
#     CR: 0.67
#     Time: 0.99
#
#
#   Percobaan ke 85
#     ID : b2_96_1
#     MSE: 0.0001544
#     PSNR: 86.24
#     CR: 0.68
#     Time: 2.14
#
#
#   Percobaan ke 86
#     ID : b2_96_2
#     MSE: 0.0001533
#     PSNR: 86.28
#     CR: 0.68
#     Time: 1.75
#
#
#   Percobaan ke 87
#     ID : b2_96_3
#     MSE: 0.0001523
#     PSNR: 86.30
#     CR: 0.68
#     Time: 2.26
#
#
#   Percobaan ke 88
#     ID : b2_128_1
#     MSE: 0.0001222
#     PSNR: 87.26
#     CR: 0.68
#     Time: 2.96
#
#
#   Percobaan ke 89
#     ID : b2_128_2
#     MSE: 0.0001210
#     PSNR: 87.30
#     CR: 0.68
#     Time: 4.43
#
#
#   Percobaan ke 90
#     ID : b2_128_3
#     MSE: 0.0001214
#     PSNR: 87.29
#     CR: 0.68
#     Time: 2.32
#
#
#   Percobaan ke 91
#     ID : b3_8_1
#     MSE: 0.0101384
#     PSNR: 68.07
#     CR: 0.74
#     Time: 0.24
#
#
#   Percobaan ke 92
#     ID : b3_8_2
#     MSE: 0.0098550
#     PSNR: 68.19
#     CR: 0.74
#     Time: 0.25
#
#
#   Percobaan ke 93
#     ID : b3_8_3
#     MSE: 0.0100678
#     PSNR: 68.10
#     CR: 0.74
#     Time: 0.21
#
#
#   Percobaan ke 94
#     ID : b3_16_1
#     MSE: 0.0052104
#     PSNR: 70.96
#     CR: 0.73
#     Time: 0.36
#
#
#   Percobaan ke 95
#     ID : b3_16_2
#     MSE: 0.0052459
#     PSNR: 70.93
#     CR: 0.73
#     Time: 0.37
#
#
#   Percobaan ke 96
#     ID : b3_16_3
#     MSE: 0.0050716
#     PSNR: 71.08
#     CR: 0.74
#     Time: 0.31
#
#
#   Percobaan ke 97
#     ID : b3_32_1
#     MSE: 0.0026825
#     PSNR: 73.85
#     CR: 0.73
#     Time: 0.67
#
#
#   Percobaan ke 98
#     ID : b3_32_2
#     MSE: 0.0026836
#     PSNR: 73.84
#     CR: 0.74
#     Time: 0.52
#
#
#   Percobaan ke 99
#     ID : b3_32_3
#     MSE: 0.0027575
#     PSNR: 73.73
#     CR: 0.73
#     Time: 0.89
#
#
#   Percobaan ke 100
#     ID : b3_64_1
#     MSE: 0.0015342
#     PSNR: 76.27
#     CR: 0.74
#     Time: 1.39
#
#
#   Percobaan ke 101
#     ID : b3_64_2
#     MSE: 0.0015601
#     PSNR: 76.20
#     CR: 0.73
#     Time: 1.65
#
#
#   Percobaan ke 102
#     ID : b3_64_3
#     MSE: 0.0015260
#     PSNR: 76.30
#     CR: 0.74
#     Time: 2.49
#
#
#   Percobaan ke 103
#     ID : b3_96_1
#     MSE: 0.0011209
#     PSNR: 77.63
#     CR: 0.73
#     Time: 2.87
#
#
#   Percobaan ke 104
#     ID : b3_96_2
#     MSE: 0.0011194
#     PSNR: 77.64
#     CR: 0.73
#     Time: 3.01
#
#
#   Percobaan ke 105
#     ID : b3_96_3
#     MSE: 0.0011202
#     PSNR: 77.64
#     CR: 0.73
#     Time: 3.32
#
#
#   Percobaan ke 106
#     ID : b3_128_1
#     MSE: 0.0009096
#     PSNR: 78.54
#     CR: 0.73
#     Time: 5.22
#
#
#   Percobaan ke 107
#     ID : b3_128_2
#     MSE: 0.0009104
#     PSNR: 78.54
#     CR: 0.73
#     Time: 3.26
#
#
#   Percobaan ke 108
#     ID : b3_128_3
#     MSE: 0.0009175
#     PSNR: 78.50
#     CR: 0.73
#     Time: 3.27
#
#
#   Percobaan ke 109
#     ID : c1_8_1
#     MSE: 0.0030419
#     PSNR: 73.30
#     CR: 0.70
#     Time: 0.45
#
#
#   Percobaan ke 110
#     ID : c1_8_2
#     MSE: 0.0030345
#     PSNR: 73.31
#     CR: 0.70
#     Time: 0.38
#
#
#   Percobaan ke 111
#     ID : c1_8_3
#     MSE: 0.0030412
#     PSNR: 73.30
#     CR: 0.70
#     Time: 0.55
#
#
#   Percobaan ke 112
#     ID : c1_16_1
#     MSE: 0.0016609
#     PSNR: 75.93
#     CR: 0.70
#     Time: 0.95
#
#
#   Percobaan ke 113
#     ID : c1_16_2
#     MSE: 0.0016681
#     PSNR: 75.91
#     CR: 0.70
#     Time: 1.23
#
#
#   Percobaan ke 114
#     ID : c1_16_3
#     MSE: 0.0016678
#     PSNR: 75.91
#     CR: 0.70
#     Time: 1.84
#
#
#   Percobaan ke 115
#     ID : c1_32_1
#     MSE: 0.0009708
#     PSNR: 78.26
#     CR: 0.70
#     Time: 0.99
#
#
#   Percobaan ke 116
#     ID : c1_32_2
#     MSE: 0.0009809
#     PSNR: 78.21
#     CR: 0.70
#     Time: 1.22
#
#
#   Percobaan ke 117
#     ID : c1_32_3
#     MSE: 0.0009829
#     PSNR: 78.21
#     CR: 0.70
#     Time: 1.21
#
#
#   Percobaan ke 118
#     ID : c1_64_1
#     MSE: 0.0005847
#     PSNR: 80.46
#     CR: 0.70
#     Time: 2.53
#
#
#   Percobaan ke 119
#     ID : c1_64_2
#     MSE: 0.0005878
#     PSNR: 80.44
#     CR: 0.70
#     Time: 2.54
#
#
#   Percobaan ke 120
#     ID : c1_64_3
#     MSE: 0.0005806
#     PSNR: 80.49
#     CR: 0.70
#     Time: 3.14
#
#
#   Percobaan ke 121
#     ID : c1_96_1
#     MSE: 0.0004381
#     PSNR: 81.71
#     CR: 0.70
#     Time: 5.48
#
#
#   Percobaan ke 122
#     ID : c1_96_2
#     MSE: 0.0004379
#     PSNR: 81.72
#     CR: 0.70
#     Time: 4.08
#
#
#   Percobaan ke 123
#     ID : c1_96_3
#     MSE: 0.0004386
#     PSNR: 81.71
#     CR: 0.70
#     Time: 4.82
#
#
#   Percobaan ke 124
#     ID : c1_128_1
#     MSE: 0.0003612
#     PSNR: 82.55
#     CR: 0.70
#     Time: 5.75
#
#
#   Percobaan ke 125
#     ID : c1_128_2
#     MSE: 0.0003591
#     PSNR: 82.58
#     CR: 0.70
#     Time: 7.94
#
#
#   Percobaan ke 126
#     ID : c1_128_3
#     MSE: 0.0003589
#     PSNR: 82.58
#     CR: 0.70
#     Time: 7.76
#
#
#   Percobaan ke 127
#     ID : c2_8_1
#     MSE: 0.0017862
#     PSNR: 75.61
#     CR: 0.72
#     Time: 0.65
#
#
#   Percobaan ke 128
#     ID : c2_8_2
#     MSE: 0.0018969
#     PSNR: 75.35
#     CR: 0.72
#     Time: 0.83
#
#
#   Percobaan ke 129
#     ID : c2_8_3
#     MSE: 0.0018937
#     PSNR: 75.36
#     CR: 0.72
#     Time: 0.62
#
#
#   Percobaan ke 130
#     ID : c2_16_1
#     MSE: 0.0009075
#     PSNR: 78.55
#     CR: 0.72
#     Time: 1.19
#
#
#   Percobaan ke 131
#     ID : c2_16_2
#     MSE: 0.0009077
#     PSNR: 78.55
#     CR: 0.72
#     Time: 0.91
#
#
#   Percobaan ke 132
#     ID : c2_16_3
#     MSE: 0.0008992
#     PSNR: 78.59
#     CR: 0.72
#     Time: 0.55
#
#
#   Percobaan ke 133
#     ID : c2_32_1
#     MSE: 0.0005041
#     PSNR: 81.11
#     CR: 0.72
#     Time: 1.27
#
#
#   Percobaan ke 134
#     ID : c2_32_2
#     MSE: 0.0005084
#     PSNR: 81.07
#     CR: 0.72
#     Time: 1.63
#
#
#   Percobaan ke 135
#     ID : c2_32_3
#     MSE: 0.0005089
#     PSNR: 81.06
#     CR: 0.72
#     Time: 1.12
#
#
#   Percobaan ke 136
#     ID : c2_64_1
#     MSE: 0.0002970
#     PSNR: 83.40
#     CR: 0.72
#     Time: 2.27
#
#
#   Percobaan ke 137
#     ID : c2_64_2
#     MSE: 0.0002972
#     PSNR: 83.40
#     CR: 0.72
#     Time: 2.61
#
#
#   Percobaan ke 138
#     ID : c2_64_3
#     MSE: 0.0003005
#     PSNR: 83.35
#     CR: 0.72
#     Time: 3.72
#
#
#   Percobaan ke 139
#     ID : c2_96_1
#     MSE: 0.0002194
#     PSNR: 84.72
#     CR: 0.72
#     Time: 3.81
#
#
#   Percobaan ke 140
#     ID : c2_96_2
#     MSE: 0.0002218
#     PSNR: 84.67
#     CR: 0.72
#     Time: 4.25
#
#
#   Percobaan ke 141
#     ID : c2_96_3
#     MSE: 0.0002192
#     PSNR: 84.72
#     CR: 0.72
#     Time: 7.74
#
#
#   Percobaan ke 142
#     ID : c2_128_1
#     MSE: 0.0001798
#     PSNR: 85.58
#     CR: 0.72
#     Time: 6.48
#
#
#   Percobaan ke 143
#     ID : c2_128_2
#     MSE: 0.0001817
#     PSNR: 85.54
#     CR: 0.72
#     Time: 5.98
#
#
#   Percobaan ke 144
#     ID : c2_128_3
#     MSE: 0.0001791
#     PSNR: 85.60
#     CR: 0.72
#     Time: 5.25
#
#
#   Percobaan ke 145
#     ID : c3_8_1
#     MSE: 0.0011989
#     PSNR: 77.34
#     CR: 0.75
#     Time: 0.47
#
#
#   Percobaan ke 146
#     ID : c3_8_2
#     MSE: 0.0010955
#     PSNR: 77.73
#     CR: 0.75
#     Time: 0.51
#
#
#   Percobaan ke 147
#     ID : c3_8_3
#     MSE: 0.0010952
#     PSNR: 77.74
#     CR: 0.75
#     Time: 0.37
#
#
#   Percobaan ke 148
#     ID : c3_16_1
#     MSE: 0.0007001
#     PSNR: 79.68
#     CR: 0.75
#     Time: 0.65
#
#
#   Percobaan ke 149
#     ID : c3_16_2
#     MSE: 0.0006920
#     PSNR: 79.73
#     CR: 0.75
#     Time: 0.58
#
#
#   Percobaan ke 150
#     ID : c3_16_3
#     MSE: 0.0006873
#     PSNR: 79.76
#     CR: 0.75
#     Time: 0.69
#
#
#   Percobaan ke 151
#     ID : c3_32_1
#     MSE: 0.0003980
#     PSNR: 82.13
#     CR: 0.74
#     Time: 1.30
#
#
#   Percobaan ke 152
#     ID : c3_32_2
#     MSE: 0.0003994
#     PSNR: 82.12
#     CR: 0.74
#     Time: 2.01
#
#
#   Percobaan ke 153
#     ID : c3_32_3
#     MSE: 0.0003956
#     PSNR: 82.16
#     CR: 0.74
#     Time: 1.29
#
#
#   Percobaan ke 154
#     ID : c3_64_1
#     MSE: 0.0002427
#     PSNR: 84.28
#     CR: 0.74
#     Time: 2.49
#
#
#   Percobaan ke 155
#     ID : c3_64_2
#     MSE: 0.0002434
#     PSNR: 84.27
#     CR: 0.74
#     Time: 3.10
#
#
#   Percobaan ke 156
#     ID : c3_64_3
#     MSE: 0.0002429
#     PSNR: 84.28
#     CR: 0.74
#     Time: 2.85
#
#
#   Percobaan ke 157
#     ID : c3_96_1
#     MSE: 0.0001868
#     PSNR: 85.42
#     CR: 0.74
#     Time: 4.75
#
#
#   Percobaan ke 158
#     ID : c3_96_2
#     MSE: 0.0001845
#     PSNR: 85.47
#     CR: 0.74
#     Time: 4.16
#
#
#   Percobaan ke 159
#     ID : c3_96_3
#     MSE: 0.0001850
#     PSNR: 85.46
#     CR: 0.74
#     Time: 3.30
#
#
#   Percobaan ke 160
#     ID : c3_128_1
#     MSE: 0.0001519
#     PSNR: 86.32
#     CR: 0.74
#     Time: 5.93
#
#
#   Percobaan ke 161
#     ID : c3_128_2
#     MSE: 0.0001519
#     PSNR: 86.32
#     CR: 0.74
#     Time: 6.41
#
#
#   Percobaan ke 162
#     ID : c3_128_3
#     MSE: 0.0001524
#     PSNR: 86.30
#     CR: 0.74
#     Time: 7.10
#
#
#   Percobaan ke 163
#     ID : d1_8_1
#     MSE: 0.0031073
#     PSNR: 73.21
#     CR: 0.70
#     Time: 0.86
#
#
#   Percobaan ke 164
#     ID : d1_8_2
#     MSE: 0.0030880
#     PSNR: 73.23
#     CR: 0.71
#     Time: 0.98
#
#
#   Percobaan ke 165
#     ID : d1_8_3
#     MSE: 0.0030172
#     PSNR: 73.33
#     CR: 0.69
#     Time: 0.80
#
#
#   Percobaan ke 166
#     ID : d1_16_1
#     MSE: 0.0012778
#     PSNR: 77.07
#     CR: 0.69
#     Time: 1.07
#
#
#   Percobaan ke 167
#     ID : d1_16_2
#     MSE: 0.0012781
#     PSNR: 77.07
#     CR: 0.69
#     Time: 1.37
#
#
#   Percobaan ke 168
#     ID : d1_16_3
#     MSE: 0.0013298
#     PSNR: 76.89
#     CR: 0.69
#     Time: 1.77
#
#
#   Percobaan ke 169
#     ID : d1_32_1
#     MSE: 0.0006817
#     PSNR: 79.80
#     CR: 0.69
#     Time: 6.80
#
#
#   Percobaan ke 170
#     ID : d1_32_2
#     MSE: 0.0006834
#     PSNR: 79.78
#     CR: 0.69
#     Time: 2.75
#
#
#   Percobaan ke 171
#     ID : d1_32_3
#     MSE: 0.0006617
#     PSNR: 79.92
#     CR: 0.68
#     Time: 3.82
#
#
#   Percobaan ke 172
#     ID : d1_64_1
#     MSE: 0.0003532
#     PSNR: 82.65
#     CR: 0.69
#     Time: 9.66
#
#
#   Percobaan ke 173
#     ID : d1_64_2
#     MSE: 0.0003541
#     PSNR: 82.64
#     CR: 0.69
#     Time: 6.58
#
#
#   Percobaan ke 174
#     ID : d1_64_3
#     MSE: 0.0003545
#     PSNR: 82.63
#     CR: 0.69
#     Time: 6.95
#
#
#   Percobaan ke 175
#     ID : d1_96_1
#     MSE: 0.0002562
#     PSNR: 84.04
#     CR: 0.69
#     Time: 10.22
#
#
#   Percobaan ke 176
#     ID : d1_96_2
#     MSE: 0.0002547
#     PSNR: 84.07
#     CR: 0.69
#     Time: 9.37
#
#
#   Percobaan ke 177
#     ID : d1_96_3
#     MSE: 0.0002532
#     PSNR: 84.10
#     CR: 0.69
#     Time: 12.69
#
#
#   Percobaan ke 178
#     ID : d1_128_1
#     MSE: 0.0002030
#     PSNR: 85.06
#     CR: 0.69
#     Time: 11.09
#
#
#   Percobaan ke 179
#     ID : d1_128_2
#     MSE: 0.0002039
#     PSNR: 85.04
#     CR: 0.69
#     Time: 15.12
#
#
#   Percobaan ke 180
#     ID : d1_128_3
#     MSE: 0.0002035
#     PSNR: 85.05
#     CR: 0.69
#     Time: 12.80
#
#
#   Percobaan ke 181
#     ID : d2_8_1
#     MSE: 0.0024826
#     PSNR: 74.18
#     CR: 0.68
#     Time: 1.04
#
#
#   Percobaan ke 182
#     ID : d2_8_2
#     MSE: 0.0024149
#     PSNR: 74.30
#     CR: 0.68
#     Time: 0.85
#
#
#   Percobaan ke 183
#     ID : d2_8_3
#     MSE: 0.0023675
#     PSNR: 74.39
#     CR: 0.68
#     Time: 0.89
#
#
#   Percobaan ke 184
#     ID : d2_16_1
#     MSE: 0.0008727
#     PSNR: 78.72
#     CR: 0.67
#     Time: 1.25
#
#
#   Percobaan ke 185
#     ID : d2_16_2
#     MSE: 0.0008732
#     PSNR: 78.72
#     CR: 0.67
#     Time: 1.43
#
#
#   Percobaan ke 186
#     ID : d2_16_3
#     MSE: 0.0008909
#     PSNR: 78.63
#     CR: 0.66
#     Time: 0.99
#
#
#   Percobaan ke 187
#     ID : d2_32_1
#     MSE: 0.0003995
#     PSNR: 82.12
#     CR: 0.67
#     Time: 2.71
#
#
#   Percobaan ke 188
#     ID : d2_32_2
#     MSE: 0.0004035
#     PSNR: 82.07
#     CR: 0.67
#     Time: 4.10
#
#
#   Percobaan ke 189
#     ID : d2_32_3
#     MSE: 0.0004040
#     PSNR: 82.07
#     CR: 0.67
#     Time: 2.30
#
#
#   Percobaan ke 190
#     ID : d2_64_1
#     MSE: 0.0001912
#     PSNR: 85.32
#     CR: 0.69
#     Time: 5.15
#
#
#   Percobaan ke 191
#     ID : d2_64_2
#     MSE: 0.0001888
#     PSNR: 85.37
#     CR: 0.69
#     Time: 5.83
#
#
#   Percobaan ke 192
#     ID : d2_64_3
#     MSE: 0.0001884
#     PSNR: 85.38
#     CR: 0.69
#     Time: 5.84
#
#
#   Percobaan ke 193
#     ID : d2_96_1
#     MSE: 0.0001280
#     PSNR: 87.06
#     CR: 0.70
#     Time: 8.39
#
#
#   Percobaan ke 194
#     ID : d2_96_2
#     MSE: 0.0001295
#     PSNR: 87.01
#     CR: 0.70
#     Time: 7.80
#
#
#   Percobaan ke 195
#     ID : d2_96_3
#     MSE: 0.0001289
#     PSNR: 87.03
#     CR: 0.70
#     Time: 10.21
#
#
#   Percobaan ke 196
#     ID : d2_128_1
#     MSE: 0.0001017
#     PSNR: 88.06
#     CR: 0.70
#     Time: 12.91
#
#
#   Percobaan ke 197
#     ID : d2_128_2
#     MSE: 0.0001005
#     PSNR: 88.11
#     CR: 0.70
#     Time: 11.32
#
#
#   Percobaan ke 198
#     ID : d2_128_3
#     MSE: 0.0000996
#     PSNR: 88.15
#     CR: 0.70
#     Time: 9.47
#
#
#   Percobaan ke 199
#     ID : d3_8_1
#     MSE: 0.0021489
#     PSNR: 74.81
#     CR: 0.57
#     Time: 1.21
#
#
#   Percobaan ke 200
#     ID : d3_8_2
#     MSE: 0.0021477
#     PSNR: 74.81
#     CR: 0.57
#     Time: 0.78
#
#
#   Percobaan ke 201
#     ID : d3_8_3
#     MSE: 0.0021111
#     PSNR: 74.89
#     CR: 0.57
#     Time: 0.96
#
#
#   Percobaan ke 202
#     ID : d3_16_1
#     MSE: 0.0010632
#     PSNR: 77.86
#     CR: 0.57
#     Time: 1.38
#
#
#   Percobaan ke 203
#     ID : d3_16_2
#     MSE: 0.0010716
#     PSNR: 77.83
#     CR: 0.56
#     Time: 1.62
#
#
#   Percobaan ke 204
#     ID : d3_16_3
#     MSE: 0.0010422
#     PSNR: 77.95
#     CR: 0.56
#     Time: 1.10
#
#
#   Percobaan ke 205
#     ID : d3_32_1
#     MSE: 0.0004990
#     PSNR: 81.15
#     CR: 0.56
#     Time: 3.26
#
#
#   Percobaan ke 206
#     ID : d3_32_2
#     MSE: 0.0005027
#     PSNR: 81.12
#     CR: 0.56
#     Time: 4.19
#
#
#   Percobaan ke 207
#     ID : d3_32_3
#     MSE: 0.0005009
#     PSNR: 81.13
#     CR: 0.56
#     Time: 2.83
#
#
#   Percobaan ke 208
#     ID : d3_64_1
#     MSE: 0.0002725
#     PSNR: 83.78
#     CR: 0.56
#     Time: 7.47
#
#
#   Percobaan ke 209
#     ID : d3_64_2
#     MSE: 0.0002681
#     PSNR: 83.85
#     CR: 0.56
#     Time: 5.89
#
#
#   Percobaan ke 210
#     ID : d3_64_3
#     MSE: 0.0002688
#     PSNR: 83.84
#     CR: 0.56
#     Time: 7.54
#
#
#   Percobaan ke 211
#     ID : d3_96_1
#     MSE: 0.0001911
#     PSNR: 85.32
#     CR: 0.56
#     Time: 8.35
#
#
#   Percobaan ke 212
#     ID : d3_96_2
#     MSE: 0.0001923
#     PSNR: 85.29
#     CR: 0.56
#     Time: 10.90
#
#
#   Percobaan ke 213
#     ID : d3_96_3
#     MSE: 0.0001914
#     PSNR: 85.31
#     CR: 0.56
#     Time: 9.67
#
#
#   Percobaan ke 214
#     ID : d3_128_1
#     MSE: 0.0001523
#     PSNR: 86.30
#     CR: 0.56
#     Time: 12.45
#
#
#   Percobaan ke 215
#     ID : d3_128_2
#     MSE: 0.0001516
#     PSNR: 86.32
#     CR: 0.56
#     Time: 16.31
#
#
#   Percobaan ke 216
#     ID : d3_128_3
#     MSE: 0.0001521
#     PSNR: 86.31
#     CR: 0.56
#     Time: 15.38
#
# total computational time 9.910614295800526 minutes

# %%
# print(result)
# SAVE TO CSV

# CREATE RESULT file name
now = datetime.datetime.now()

# Adjust for GMT+7
offset_hours = 7
now = now + datetime.timedelta(hours=offset_hours)

formatted_datetime = now.strftime("%y%m%d_%H-%M")

resultfile = f"{resultpath}/result-{formatted_datetime}.csv"

with open(resultfile, "w", newline="") as csvfile:
  writer = csv.writer(csvfile)
  writer.writerow(csv_headers)  # Write header row
  writer.writerows(result)  # Write data rows

print("CSV file saved successfully!")
# Out:
# CSV file saved successfully!

# %%
# DOWNLOAD THE RESULT
from google.colab import files
import shutil

shutil.make_archive(resultpath, 'zip', resultpath)
files.download(f"{resultpath}.zip")

# %% [markdown]
# # uji coba gambar lain diluar dataset. asumsi nilai k optimal = 96

# %%
k = 96
test_file = "test-img.jpeg"
start_time = time()  # Start time measurement
image = load_img(test_file)
palette, k_means = get_color_palette(image, k)

quantized_img = quantize_img(image, k_means)
save_quantized_img(quantized_img, "result.jpg", 0.6)

img_np = np.asarray(image) / 255.0
mse, psnr = calculate_mse_psnr_metrics(
    img_np, quantized_img)

compression_ratio, original_size, compressed_size =  calculate_compression_ratio(
    test_file, "result.jpg")
computation_time = time() - start_time
# CONVERT THE VALUE INTO float positional notation
converted_mse = f"{mse:.7f}"
converted_psnr = f"{psnr:.2f}"
converted_compression_ratio = f"{compression_ratio:.2f}"
converted_computation_time = f"{computation_time:.2f}"

print(f"""
  MSE: {converted_mse}
  PSNR: {converted_psnr}
  CR: {converted_compression_ratio}
  TIME : {converted_computation_time}
""")
# Out:
#   MSE: 0.0001542
#   PSNR: 86.25
#   CR: 0.29
#   TIME : 25.42
